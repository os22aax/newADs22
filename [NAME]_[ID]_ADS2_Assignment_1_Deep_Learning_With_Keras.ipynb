# %% [markdown]
# # Assignment 1 - Deep Learning With Keras - 40%
#
# **IMPORTANT NOTE**: By default, this notebook is set to a CPU runtime, to help prevent you getting locked out of Google Colab. When training your models, you will need to switch to a GPU runtime, otherwise the training will take a very long time.
#
# **Deadline**: 21 Mar 2023, 23:59
#
# **Submission Requirements**: You should submit your Colab Notebook, with all the outputs printed, and a sharing link to the notebook in your Drive. As detailed above, you should submit a 2-page report in PDF or DOCX format.
#
# **Learning Outcomes**
#
# This Assignment assesses the following module Learning Outcomes (from Definitive Module Document):
#
# * have knowledge of and understand how GPUs can accelerate data processing
# * be able to write data processing pipelines that exploit Tensorflow
# * have knowledge of and understand how to develop GPU-accelerated data processing pipelines using the Tensorflow and RAPIDS frameworks
#
# **Assignment Details**
#
# This assignment will test your ability to implement and test a deep neural network using keras. By varying the properties of the model and the data input pipeline, you will explore and analyse the training time and performance of the model. There will be four tasks for you to complete, each of which requires you to complete a range of tests on the model, visualise the results, and comment on them in a short report. Your report should focus on explaining and critically analysing the results—you will be assessed not just on your ability to show what is happening, but explain WHY it is happening.
#
# All coding work for this assignment should be done inside a copy of the Colab Notebook provided on this page. Any submissions not in this format will not be marked.
#
# **Task 1**: A model description is provided in the Colab Notebook for this assignment. Implement this model, ensuring that you have the correct output shapes for each of the layers and the correct number of model parameters. Train the model on the dataset provided in the notebook—initial training settings are provided also. Create plots of the losses and metrics of the training and validation data, and a plot that shows example images from each class that have been correctly AND incorrectly labelled by the model. Analyse these results in your report.
#
# **Task 2**: Select two additional optimizers. Including the one provided in the initial training settings, test your model with each of these optimizers using a range of different learning rates. You may need to train the model for more epochs to ensure that it converges on a solution. Create plots that show the losses and metrics for each of these runs, and comment on the results in your report. Select the optimizer and learning rate that provided the best results, and move onto the next task.
#
# **Task 3**: The batch size can heavily influence the amount of time it takes to train a model. Vary the batch size used to train the model and, utilising the Early Stopping callback provided, create plots that show how the time per epoch and total training time changes. Comment on these results in your report.
#
# **Task 4**: The model as provided does not contain any regularisation techniques. Edit the model architecture to include at least two examples of regularisation. Retrain the model using the new architecture, and repeat the analysis performed in task 1. In your report, compare and contrast the results from this task, with those from the initial model configuration.

# %%
# Module Imports - Add any additional modules here
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models, optimizers, losses, callbacks,\
                             regularizers

# %%
# Loading the Dataset. Here we use the CIFAR-10 dataset of labelled images

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# Rescale the pixel values
x_train = x_train/255.
x_test = x_test/255.

# List of label names
class_names = ['plane', 'car', 'bird', 'cat', 'deer',
               'canine', 'frog', 'horse', 'boat', 'truck']
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 6s 0us/step

# %% [markdown]
# # Task 1 - Initial Model
#
# Implement the model architecture detailed below, using the Keras Functional API, ensuring that you have the correct output shapes for each of the layers.
#
# Train the model on the CIFAR-10 dataset.
#
# Create plots of the losses and metrics of the training and validation data, and plots that show example test images from each class that have been correctly AND incorrectly labelled by the model.
#
# Analyse these results in your report.
#
# **Model Architecture**
#
# A summary of the model architecture is given here, which shows the layers of the model, the output shapes of those layers, and the activation functions used. You will need to work out the other settings used to produce the model, such as the kernal sizes, padding schemes, and stride lengths. You should ensure that the output shapes and total number of parameters in your model match the summary here.
#
# ```
# Model: "cifar_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Activation
# =================================================================
#  Input (InputLayer)          [(None, 32, 32, 3)]       None
#
#  conv_1 (Conv2D)             (None, 32, 32, 16)        ReLU
#
#  conv_2 (Conv2D)             (None, 32, 32, 16)        ReLU
#
#  pool_1 (MaxPooling2D)       (None, 16, 16, 16)        None
#
#  conv_3 (Conv2D)             (None, 16, 16, 32)        ReLU
#
#  conv_4 (Conv2D)             (None, 16, 16, 32)        ReLU
#
#  pool_2 (MaxPooling2D)       (None, 8, 8, 32)          None
#
#  conv_5 (Conv2D)             (None, 8, 8, 64)          ReLU
#
#  conv_6 (Conv2D)             (None, 8, 8, 64)          ReLU
#
#  pool_3 (MaxPooling2D)       (None, 4, 4, 64)          None
#
#  flat (Flatten)              (None, 1024)              None
#
#  fc_1 (Dense)                (None, 512)               ReLU
#
#  Output (Dense)              (None, 10)                SoftMax
#
# =================================================================
# Total params: 602,010
# Trainable params: 602,010
# Non-trainable params: 0
# _________________________________________________________________
# ```

# %%
### Create the model using the provided architecture
Inp = layers.Input((32,32,3), dtype='float32', name='Input')
Conv1 = layers.Conv2D(16, kernel_size=(3,3), activation='relu',
                      padding='same', name='conv_1')(Inp)
Conv2 = layers.Conv2D(16, kernel_size=(3,3), activation='relu',
                      padding='same', name='conv_2')(Conv1)
Pool1 = layers.MaxPool2D(pool_size=(2,2),
                         name='pool_1')(Conv2)
Conv3 = layers.Conv2D(32, kernel_size=(3,3), activation='relu',
                      padding='same', name='conv_3')(Pool1)
Conv4 = layers.Conv2D(32, kernel_size=(3,3), activation='relu',
                      padding='same', name='conv_4')(Conv3)
Pool2 = layers.MaxPool2D(pool_size=(2,2),
                         name='pool_2')(Conv4)
Conv5 = layers.Conv2D(64, kernel_size=(3,3), activation='relu',
                      padding='same', name='conv_5')(Pool2)
Conv6 = layers.Conv2D(64, kernel_size=(3,3), activation='relu',
                      padding='same', name='conv_6')(Conv5)
Pool3 = layers.MaxPool2D(pool_size=(2,2),
                         name='pool_3')(Conv6)

Flat = layers.Flatten()(Pool3)
Dense1 = layers.Dense(512, activation='relu', name='fc_1')(Flat)
Dense2 = layers.Dense(10,activation='softmax', name='fc_2')(Dense1)

cifar_model = models.Model(inputs=Inp, outputs=Dense2)
cifar_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 32, 32, 3)]       0
#
#  conv_1 (Conv2D)             (None, 32, 32, 16)        448
#
#  conv_2 (Conv2D)             (None, 32, 32, 16)        2320
#
#  pool_1 (MaxPooling2D)       (None, 16, 16, 16)        0
#
#  conv_3 (Conv2D)             (None, 16, 16, 32)        4640
#
#  conv_4 (Conv2D)             (None, 16, 16, 32)        9248
#
#  pool_2 (MaxPooling2D)       (None, 8, 8, 32)          0
#
#  conv_5 (Conv2D)             (None, 8, 8, 64)          18496
#
#  conv_6 (Conv2D)             (None, 8, 8, 64)          36928
#
#  pool_3 (MaxPooling2D)       (None, 4, 4, 64)          0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  fc_1 (Dense)                (None, 512)               524800
#
#  fc_2 (Dense)                (None, 10)                5130
#
# =================================================================
# Total params: 602,010
# Trainable params: 602,010
# Non-trainable params: 0
# _________________________________________________________________

# %%
### Compile the model using the SGC optimizer, with default learning rate,
### Sparse Categorical Crossentropy, and accuracy metric.
cifar_model.compile(optimizer=optimizers.SGD(),
                    loss=losses.SparseCategoricalCrossentropy(from_logits=True),
                    metrics=['accuracy'])

# %%
### Train the model for 50 epochs, with a batch size of 128. Include the test
### data for model validation. Store the losses and metrics in a history object.
history = cifar_model.fit(x=x_train, y=y_train, epochs=50,
                          validation_data=(x_test, y_test),
                          batch_size=128)
print(history.history.keys)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.9/dist-packages/keras/backend.py:5585: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 391/391 [==============================] - 14s 11ms/step - loss: 2.2972 - accuracy: 0.1422 - val_loss: 2.2854 - val_accuracy: 0.1957
# Epoch 2/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.1865 - accuracy: 0.2142 - val_loss: 1.9942 - val_accuracy: 0.2770
# Epoch 3/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.9713 - accuracy: 0.2904 - val_loss: 1.8557 - val_accuracy: 0.3359
# Epoch 4/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.8151 - accuracy: 0.3526 - val_loss: 1.7751 - val_accuracy: 0.3716
# Epoch 5/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.6734 - accuracy: 0.4054 - val_loss: 1.7244 - val_accuracy: 0.3897
# Epoch 6/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.5783 - accuracy: 0.4412 - val_loss: 1.5626 - val_accuracy: 0.4456
# Epoch 7/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.5038 - accuracy: 0.4679 - val_loss: 1.4703 - val_accuracy: 0.4781
# Epoch 8/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.4414 - accuracy: 0.4871 - val_loss: 1.4335 - val_accuracy: 0.4924
# Epoch 9/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.3933 - accuracy: 0.5075 - val_loss: 1.3740 - val_accuracy: 0.5110
# Epoch 10/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.3541 - accuracy: 0.5212 - val_loss: 1.4405 - val_accuracy: 0.4825
# Epoch 11/50
# 391/391 [==============================] - 4s 9ms/step - loss: 1.3152 - accuracy: 0.5361 - val_loss: 1.3467 - val_accuracy: 0.5181
# Epoch 12/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.2781 - accuracy: 0.5492 - val_loss: 1.3378 - val_accuracy: 0.5244
# Epoch 13/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.2427 - accuracy: 0.5620 - val_loss: 1.2799 - val_accuracy: 0.5475
# Epoch 14/50
# 391/391 [==============================] - 3s 9ms/step - loss: 1.2082 - accuracy: 0.5744 - val_loss: 1.2620 - val_accuracy: 0.5558
# Epoch 15/50
# 391/391 [==============================] - 3s 9ms/step - loss: 1.1732 - accuracy: 0.5880 - val_loss: 1.2271 - val_accuracy: 0.5647
# Epoch 16/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.1409 - accuracy: 0.6002 - val_loss: 1.2078 - val_accuracy: 0.5798
# Epoch 17/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.1135 - accuracy: 0.6095 - val_loss: 1.2162 - val_accuracy: 0.5708
# Epoch 18/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.0830 - accuracy: 0.6194 - val_loss: 1.1988 - val_accuracy: 0.5819
# Epoch 19/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.0536 - accuracy: 0.6315 - val_loss: 1.1885 - val_accuracy: 0.5809
# Epoch 20/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.0272 - accuracy: 0.6411 - val_loss: 1.1709 - val_accuracy: 0.5945
# Epoch 21/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.9983 - accuracy: 0.6508 - val_loss: 1.1903 - val_accuracy: 0.5850
# Epoch 22/50
# 391/391 [==============================] - 4s 9ms/step - loss: 0.9722 - accuracy: 0.6605 - val_loss: 1.1720 - val_accuracy: 0.5946
# Epoch 23/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.9475 - accuracy: 0.6693 - val_loss: 1.1266 - val_accuracy: 0.6050
# Epoch 24/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.9250 - accuracy: 0.6789 - val_loss: 1.2167 - val_accuracy: 0.5796
# Epoch 25/50
# 391/391 [==============================] - 4s 9ms/step - loss: 0.8944 - accuracy: 0.6895 - val_loss: 1.1593 - val_accuracy: 0.5996
# Epoch 26/50
# 391/391 [==============================] - 3s 9ms/step - loss: 0.8702 - accuracy: 0.6962 - val_loss: 1.1451 - val_accuracy: 0.6103
# Epoch 27/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.8442 - accuracy: 0.7061 - val_loss: 1.1362 - val_accuracy: 0.6102
# Epoch 28/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.8204 - accuracy: 0.7141 - val_loss: 1.1253 - val_accuracy: 0.6169
# Epoch 29/50
# 391/391 [==============================] - 4s 10ms/step - loss: 0.7939 - accuracy: 0.7242 - val_loss: 1.1353 - val_accuracy: 0.6169
# Epoch 30/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.7727 - accuracy: 0.7321 - val_loss: 1.1864 - val_accuracy: 0.6125
# Epoch 31/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.7440 - accuracy: 0.7407 - val_loss: 1.1763 - val_accuracy: 0.6074
# Epoch 32/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.7213 - accuracy: 0.7477 - val_loss: 1.1763 - val_accuracy: 0.6177
# Epoch 33/50
# 391/391 [==============================] - 4s 10ms/step - loss: 0.6960 - accuracy: 0.7591 - val_loss: 1.1539 - val_accuracy: 0.6208
# Epoch 34/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.6670 - accuracy: 0.7675 - val_loss: 1.1646 - val_accuracy: 0.6161
# Epoch 35/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.6442 - accuracy: 0.7749 - val_loss: 1.3472 - val_accuracy: 0.5819
# Epoch 36/50
# 391/391 [==============================] - 3s 9ms/step - loss: 0.6185 - accuracy: 0.7821 - val_loss: 1.2145 - val_accuracy: 0.6249
# Epoch 37/50
# 391/391 [==============================] - 3s 9ms/step - loss: 0.5937 - accuracy: 0.7929 - val_loss: 1.1943 - val_accuracy: 0.6243
# Epoch 38/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.5663 - accuracy: 0.8019 - val_loss: 1.2810 - val_accuracy: 0.6168
# Epoch 39/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.5440 - accuracy: 0.8106 - val_loss: 1.4997 - val_accuracy: 0.5876
# Epoch 40/50
# 391/391 [==============================] - 4s 9ms/step - loss: 0.5197 - accuracy: 0.8188 - val_loss: 1.3707 - val_accuracy: 0.6073
# Epoch 41/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.4907 - accuracy: 0.8270 - val_loss: 1.4088 - val_accuracy: 0.6067
# Epoch 42/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.4721 - accuracy: 0.8342 - val_loss: 1.3564 - val_accuracy: 0.6282
# Epoch 43/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.4486 - accuracy: 0.8411 - val_loss: 1.5279 - val_accuracy: 0.6064
# Epoch 44/50
# 391/391 [==============================] - 4s 10ms/step - loss: 0.4212 - accuracy: 0.8520 - val_loss: 1.4407 - val_accuracy: 0.6250
# Epoch 45/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.3971 - accuracy: 0.8613 - val_loss: 1.5327 - val_accuracy: 0.6046
# Epoch 46/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.3649 - accuracy: 0.8703 - val_loss: 1.5577 - val_accuracy: 0.6113
# Epoch 47/50
# 391/391 [==============================] - 4s 9ms/step - loss: 0.3513 - accuracy: 0.8748 - val_loss: 1.6253 - val_accuracy: 0.6146
# Epoch 48/50
# 391/391 [==============================] - 4s 9ms/step - loss: 0.3255 - accuracy: 0.8842 - val_loss: 1.6566 - val_accuracy: 0.6157
# Epoch 49/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.2978 - accuracy: 0.8959 - val_loss: 1.7502 - val_accuracy: 0.6035
# Epoch 50/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.2797 - accuracy: 0.9014 - val_loss: 1.8670 - val_accuracy: 0.5904
# <built-in method keys of dict object at 0x7fabf803d5c0>

# %%
### Create plots of the losses and metrics of the training and validation data,
### and plots that shows example test images from each class that have been
### correctly AND incorrectly labelled by the model.
plt.figure()
plt.plot(history.history['loss'], label='Training')
plt.plot(history.history['val_loss'], label='Validation')
plt.legend()
plt.title('Model Loss')


plt.figure()
plt.plot(history.history['accuracy'], label='Training')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.legend()
plt.title('Model Accuracy')

plt.show()

prediction_model = models.Sequential([cifar_model, layers.Softmax()])
y_pred = prediction_model.predict(x_test)
y_pred_label = np.argmax(y_pred, axis=1)

#y_test = y_test.reshape(-1,)
f, ax = plt.subplots(5,2, figsize=(10, 12))
ax = ax.flatten()
y_test = y_test.reshape(-1,)
for i in range(10):
    ax[i].imshow(x_test[i])
    ax[i].set_title(f'Truth = {class_names[y_test[i]]}\nPred = {class_names[y_pred_label[i]]}')
    ax[i].set_xticks([])
    ax[i].set_yticks([])

plt.show()
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# # Task 2 - Testing Optimizers
#
# Select two additional optimizers. Including the SGD algorithm already used, test all three of these optimizers with a range of different learning rates.
#
# You may need to train the model for more or less epochs to ensure that it converges on a solution.
#
# Create plots that show the losses and metrics for each of these runs, and comment on the results in your report.
#
# Select the optimizer and learning rate that provided the best results, and move onto the next task.
#
# **Note**: You should reset the weights of the model between each test. A function is provided to perform this task. Store the losses and metrics of each run under a different variable name, so that they can all be plotted together.

# %%
# Utility function that resets the weights of your model. Call this before
# recompiling your model with updated settings, to ensure you train the model
# from scratch.

def reinitialize(model):
    # Loop over the layers of the model
    for l in model.layers:
        # Check if the layer has initializers
        if hasattr(l,"kernel_initializer"):
            # Reset the kernel weights
            l.kernel.assign(l.kernel_initializer(tf.shape(l.kernel)))
        if hasattr(l,"bias_initializer"):
            # Reset the bias
            l.bias.assign(l.bias_initializer(tf.shape(l.bias)))

# Function modified from here: https://stackoverflow.com/questions/63435679/reset-all-weights-of-keras-model

# %%
### Test the SGD Optimizer, plus two others of your choice, with a range of
### learning rates.
opt=optimizers.SGD(learning_rate=0.0001)
reinitialize(cifar_model)
cifar_model.compile(optimizer= opt,
                    loss=losses.SparseCategoricalCrossentropy(from_logits=True),
                    metrics=['accuracy'],)

history_S_1 = cifar_model.fit(x=x_train, y=y_train, epochs=50,
                          validation_data=(x_test, y_test),
                          batch_size=128)
print(history_S_1.history.keys)

opt=optimizers.Adam()
reinitialize(cifar_model)
cifar_model.compile(optimizer= opt,
                    loss=losses.SparseCategoricalCrossentropy(from_logits=True),
                    metrics=['accuracy'],)

history_1 = cifar_model.fit(x=x_train, y=y_train, epochs=50,
                          validation_data=(x_test, y_test),
                          batch_size=128)
print(history_1.history.keys)

reinitialize(cifar_model)
opt_1=optimizers.Adam(learning_rate=0.0001)
cifar_model.compile(optimizer= opt_1,
                    loss=losses.SparseCategoricalCrossentropy(from_logits=True),
                    metrics=['accuracy'])

history_1_A = cifar_model.fit(x=x_train, y=y_train, epochs=50,
                          validation_data=(x_test, y_test),
                          batch_size=128)
print(history_1_A.history.keys)

reinitialize(cifar_model)
opt_3=optimizers.RMSprop()
cifar_model.compile(optimizer= opt_3,
                    loss=losses.SparseCategoricalCrossentropy(from_logits=True),
                    metrics=['accuracy'])

history_2 = cifar_model.fit(x=x_train, y=y_train, epochs=50,
                          validation_data=(x_test, y_test),
                          batch_size=128)
print(history_2.history.keys)

reinitialize(cifar_model)
opt_4=optimizers.RMSprop(learning_rate=0.0001)
cifar_model.compile(optimizer= opt_4,
                    loss=losses.SparseCategoricalCrossentropy(from_logits=True),
                    metrics=['accuracy'])

history_2_A = cifar_model.fit(x=x_train, y=y_train, epochs=50,
                          validation_data=(x_test, y_test),
                          batch_size=128)
print(history_2_A.history.keys)
# Out:
# /usr/local/lib/python3.9/dist-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer GlorotUniform is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# Epoch 1/50
# /usr/local/lib/python3.9/dist-packages/keras/backend.py:5585: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 391/391 [==============================] - 5s 9ms/step - loss: 2.3039 - accuracy: 0.0985 - val_loss: 2.3038 - val_accuracy: 0.1001
# Epoch 2/50
# 391/391 [==============================] - 4s 9ms/step - loss: 2.3037 - accuracy: 0.0979 - val_loss: 2.3036 - val_accuracy: 0.0997
# Epoch 3/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3036 - accuracy: 0.0976 - val_loss: 2.3035 - val_accuracy: 0.0994
# Epoch 4/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3034 - accuracy: 0.0974 - val_loss: 2.3033 - val_accuracy: 0.0992
# Epoch 5/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3033 - accuracy: 0.0974 - val_loss: 2.3032 - val_accuracy: 0.0989
# Epoch 6/50
# 391/391 [==============================] - 4s 9ms/step - loss: 2.3031 - accuracy: 0.0973 - val_loss: 2.3030 - val_accuracy: 0.0982
# Epoch 7/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3030 - accuracy: 0.0972 - val_loss: 2.3029 - val_accuracy: 0.0981
# Epoch 8/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3029 - accuracy: 0.0977 - val_loss: 2.3027 - val_accuracy: 0.0983
# Epoch 9/50
# 391/391 [==============================] - 4s 9ms/step - loss: 2.3027 - accuracy: 0.0979 - val_loss: 2.3026 - val_accuracy: 0.0986
# Epoch 10/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3026 - accuracy: 0.0979 - val_loss: 2.3025 - val_accuracy: 0.0992
# Epoch 11/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3025 - accuracy: 0.0987 - val_loss: 2.3023 - val_accuracy: 0.1011
# Epoch 12/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3023 - accuracy: 0.0993 - val_loss: 2.3022 - val_accuracy: 0.1025
# Epoch 13/50
# 391/391 [==============================] - 4s 10ms/step - loss: 2.3022 - accuracy: 0.1005 - val_loss: 2.3021 - val_accuracy: 0.1037
# Epoch 14/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3021 - accuracy: 0.1021 - val_loss: 2.3020 - val_accuracy: 0.1051
# Epoch 15/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3020 - accuracy: 0.1041 - val_loss: 2.3018 - val_accuracy: 0.1080
# Epoch 16/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3018 - accuracy: 0.1065 - val_loss: 2.3017 - val_accuracy: 0.1097
# Epoch 17/50
# 391/391 [==============================] - 4s 9ms/step - loss: 2.3017 - accuracy: 0.1096 - val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 18/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3016 - accuracy: 0.1124 - val_loss: 2.3015 - val_accuracy: 0.1165
# Epoch 19/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3015 - accuracy: 0.1152 - val_loss: 2.3014 - val_accuracy: 0.1180
# Epoch 20/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3014 - accuracy: 0.1183 - val_loss: 2.3012 - val_accuracy: 0.1228
# Epoch 21/50
# 391/391 [==============================] - 4s 9ms/step - loss: 2.3012 - accuracy: 0.1224 - val_loss: 2.3011 - val_accuracy: 0.1261
# Epoch 22/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3011 - accuracy: 0.1264 - val_loss: 2.3010 - val_accuracy: 0.1284
# Epoch 23/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3010 - accuracy: 0.1313 - val_loss: 2.3009 - val_accuracy: 0.1333
# Epoch 24/50
# 391/391 [==============================] - 4s 10ms/step - loss: 2.3009 - accuracy: 0.1356 - val_loss: 2.3008 - val_accuracy: 0.1364
# Epoch 25/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3008 - accuracy: 0.1389 - val_loss: 2.3007 - val_accuracy: 0.1407
# Epoch 26/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3007 - accuracy: 0.1430 - val_loss: 2.3005 - val_accuracy: 0.1445
# Epoch 27/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3006 - accuracy: 0.1464 - val_loss: 2.3004 - val_accuracy: 0.1500
# Epoch 28/50
# 391/391 [==============================] - 4s 9ms/step - loss: 2.3004 - accuracy: 0.1494 - val_loss: 2.3003 - val_accuracy: 0.1542
# Epoch 29/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3003 - accuracy: 0.1528 - val_loss: 2.3002 - val_accuracy: 0.1565
# Epoch 30/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3002 - accuracy: 0.1561 - val_loss: 2.3001 - val_accuracy: 0.1593
# Epoch 31/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3001 - accuracy: 0.1588 - val_loss: 2.3000 - val_accuracy: 0.1610
# Epoch 32/50
# 391/391 [==============================] - 4s 9ms/step - loss: 2.3000 - accuracy: 0.1617 - val_loss: 2.2999 - val_accuracy: 0.1634
# Epoch 33/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.2999 - accuracy: 0.1634 - val_loss: 2.2998 - val_accuracy: 0.1649
# Epoch 34/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.2998 - accuracy: 0.1651 - val_loss: 2.2996 - val_accuracy: 0.1653
# Epoch 35/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.2997 - accuracy: 0.1673 - val_loss: 2.2995 - val_accuracy: 0.1668
# Epoch 36/50
# 391/391 [==============================] - 4s 9ms/step - loss: 2.2996 - accuracy: 0.1682 - val_loss: 2.2994 - val_accuracy: 0.1691
# Epoch 37/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.2994 - accuracy: 0.1692 - val_loss: 2.2993 - val_accuracy: 0.1704
# Epoch 38/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.2993 - accuracy: 0.1698 - val_loss: 2.2992 - val_accuracy: 0.1722
# Epoch 39/50
# 391/391 [==============================] - 3s 9ms/step - loss: 2.2992 - accuracy: 0.1705 - val_loss: 2.2991 - val_accuracy: 0.1723
# Epoch 40/50
# 391/391 [==============================] - 3s 9ms/step - loss: 2.2991 - accuracy: 0.1706 - val_loss: 2.2990 - val_accuracy: 0.1730
# Epoch 41/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.2990 - accuracy: 0.1715 - val_loss: 2.2989 - val_accuracy: 0.1733
# Epoch 42/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.2989 - accuracy: 0.1719 - val_loss: 2.2987 - val_accuracy: 0.1742
# Epoch 43/50
# 391/391 [==============================] - 4s 9ms/step - loss: 2.2988 - accuracy: 0.1722 - val_loss: 2.2986 - val_accuracy: 0.1744
# Epoch 44/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.2987 - accuracy: 0.1731 - val_loss: 2.2985 - val_accuracy: 0.1748
# Epoch 45/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.2985 - accuracy: 0.1727 - val_loss: 2.2984 - val_accuracy: 0.1752
# Epoch 46/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.2984 - accuracy: 0.1738 - val_loss: 2.2983 - val_accuracy: 0.1753
# Epoch 47/50
# 391/391 [==============================] - 4s 9ms/step - loss: 2.2983 - accuracy: 0.1740 - val_loss: 2.2981 - val_accuracy: 0.1751
# Epoch 48/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.2982 - accuracy: 0.1744 - val_loss: 2.2980 - val_accuracy: 0.1752
# Epoch 49/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.2980 - accuracy: 0.1744 - val_loss: 2.2979 - val_accuracy: 0.1756
# Epoch 50/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.2979 - accuracy: 0.1747 - val_loss: 2.2978 - val_accuracy: 0.1761
# <built-in method keys of dict object at 0x7fab1960fb80>
# Epoch 1/50
# 391/391 [==============================] - 7s 10ms/step - loss: 1.5606 - accuracy: 0.4285 - val_loss: 1.3113 - val_accuracy: 0.5212
# Epoch 2/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.1498 - accuracy: 0.5889 - val_loss: 1.0340 - val_accuracy: 0.6365
# Epoch 3/50
# 391/391 [==============================] - 4s 10ms/step - loss: 0.9535 - accuracy: 0.6633 - val_loss: 0.9087 - val_accuracy: 0.6790
# Epoch 4/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.8187 - accuracy: 0.7107 - val_loss: 0.8572 - val_accuracy: 0.6984
# Epoch 5/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.7113 - accuracy: 0.7500 - val_loss: 0.7705 - val_accuracy: 0.7268
# Epoch 6/50
# 391/391 [==============================] - 3s 9ms/step - loss: 0.6244 - accuracy: 0.7816 - val_loss: 0.7851 - val_accuracy: 0.7313
# Epoch 7/50
# 391/391 [==============================] - 4s 9ms/step - loss: 0.5441 - accuracy: 0.8103 - val_loss: 0.7544 - val_accuracy: 0.7428
# Epoch 8/50
# 391/391 [==============================] - 3s 9ms/step - loss: 0.4585 - accuracy: 0.8402 - val_loss: 0.8138 - val_accuracy: 0.7349
# Epoch 9/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.3818 - accuracy: 0.8649 - val_loss: 0.8515 - val_accuracy: 0.7288
# Epoch 10/50
# 391/391 [==============================] - 4s 10ms/step - loss: 0.3134 - accuracy: 0.8883 - val_loss: 0.8755 - val_accuracy: 0.7486
# Epoch 11/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.2529 - accuracy: 0.9113 - val_loss: 0.9884 - val_accuracy: 0.7382
# Epoch 12/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.2040 - accuracy: 0.9279 - val_loss: 1.0459 - val_accuracy: 0.7375
# Epoch 13/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.1566 - accuracy: 0.9449 - val_loss: 1.1117 - val_accuracy: 0.7395
# Epoch 14/50
# 391/391 [==============================] - 4s 10ms/step - loss: 0.1307 - accuracy: 0.9548 - val_loss: 1.2317 - val_accuracy: 0.7435
# Epoch 15/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.1163 - accuracy: 0.9587 - val_loss: 1.3119 - val_accuracy: 0.7424
# Epoch 16/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.1023 - accuracy: 0.9638 - val_loss: 1.3743 - val_accuracy: 0.7390
# Epoch 17/50
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0976 - accuracy: 0.9666 - val_loss: 1.3451 - val_accuracy: 0.7358
# Epoch 18/50
# 391/391 [==============================] - 3s 9ms/step - loss: 0.0729 - accuracy: 0.9745 - val_loss: 1.5216 - val_accuracy: 0.7376
# Epoch 19/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0938 - accuracy: 0.9675 - val_loss: 1.4417 - val_accuracy: 0.7443
# Epoch 20/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0764 - accuracy: 0.9735 - val_loss: 1.5942 - val_accuracy: 0.7370
# Epoch 21/50
# 391/391 [==============================] - 4s 10ms/step - loss: 0.0744 - accuracy: 0.9746 - val_loss: 1.6563 - val_accuracy: 0.7201
# Epoch 22/50
# 391/391 [==============================] - 3s 9ms/step - loss: 0.0810 - accuracy: 0.9727 - val_loss: 1.6088 - val_accuracy: 0.7422
# Epoch 23/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0730 - accuracy: 0.9749 - val_loss: 1.6299 - val_accuracy: 0.7452
# Epoch 24/50
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0642 - accuracy: 0.9779 - val_loss: 1.7247 - val_accuracy: 0.7366
# Epoch 25/50
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0681 - accuracy: 0.9766 - val_loss: 1.7638 - val_accuracy: 0.7431
# Epoch 26/50
# 391/391 [==============================] - 3s 9ms/step - loss: 0.0553 - accuracy: 0.9810 - val_loss: 1.8777 - val_accuracy: 0.7368
# Epoch 27/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0728 - accuracy: 0.9747 - val_loss: 1.7527 - val_accuracy: 0.7380
# Epoch 28/50
# 391/391 [==============================] - 4s 10ms/step - loss: 0.0584 - accuracy: 0.9810 - val_loss: 1.9372 - val_accuracy: 0.7287
# Epoch 29/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0707 - accuracy: 0.9762 - val_loss: 1.9146 - val_accuracy: 0.7334
# Epoch 30/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0539 - accuracy: 0.9818 - val_loss: 1.8248 - val_accuracy: 0.7315
# Epoch 31/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0587 - accuracy: 0.9800 - val_loss: 1.9755 - val_accuracy: 0.7336
# Epoch 32/50
# 391/391 [==============================] - 4s 10ms/step - loss: 0.0634 - accuracy: 0.9793 - val_loss: 1.7622 - val_accuracy: 0.7294
# Epoch 33/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0397 - accuracy: 0.9866 - val_loss: 2.0435 - val_accuracy: 0.7316
# Epoch 34/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0586 - accuracy: 0.9799 - val_loss: 1.9350 - val_accuracy: 0.7453
# Epoch 35/50
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0521 - accuracy: 0.9820 - val_loss: 1.9798 - val_accuracy: 0.7386
# Epoch 36/50
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0651 - accuracy: 0.9785 - val_loss: 1.9978 - val_accuracy: 0.7486
# Epoch 37/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0445 - accuracy: 0.9854 - val_loss: 2.0784 - val_accuracy: 0.7345
# Epoch 38/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0579 - accuracy: 0.9809 - val_loss: 2.0667 - val_accuracy: 0.7310
# Epoch 39/50
# 391/391 [==============================] - 4s 10ms/step - loss: 0.0493 - accuracy: 0.9838 - val_loss: 2.1178 - val_accuracy: 0.7319
# Epoch 40/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0643 - accuracy: 0.9798 - val_loss: 2.0645 - val_accuracy: 0.7353
# Epoch 41/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0458 - accuracy: 0.9846 - val_loss: 2.1110 - val_accuracy: 0.7455
# Epoch 42/50
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0541 - accuracy: 0.9820 - val_loss: 2.1876 - val_accuracy: 0.7311
# Epoch 43/50
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0549 - accuracy: 0.9822 - val_loss: 2.1869 - val_accuracy: 0.7385
# Epoch 44/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0423 - accuracy: 0.9863 - val_loss: 2.1019 - val_accuracy: 0.7406
# Epoch 45/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0431 - accuracy: 0.9858 - val_loss: 2.1317 - val_accuracy: 0.7372
# Epoch 46/50
# 391/391 [==============================] - 4s 10ms/step - loss: 0.0514 - accuracy: 0.9837 - val_loss: 2.0579 - val_accuracy: 0.7399
# Epoch 47/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0485 - accuracy: 0.9845 - val_loss: 2.2424 - val_accuracy: 0.7357
# Epoch 48/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0513 - accuracy: 0.9836 - val_loss: 2.1397 - val_accuracy: 0.7339
# Epoch 49/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0460 - accuracy: 0.9851 - val_loss: 2.3067 - val_accuracy: 0.7287
# Epoch 50/50
# 391/391 [==============================] - 4s 10ms/step - loss: 0.0466 - accuracy: 0.9848 - val_loss: 2.2425 - val_accuracy: 0.7402
# <built-in method keys of dict object at 0x7fab0b5e1ec0>
# Epoch 1/5
# 391/391 [==============================] - 7s 10ms/step - loss: 1.8575 - accuracy: 0.3308 - val_loss: 1.5940 - val_accuracy: 0.4292
# Epoch 2/5
# 391/391 [==============================] - 4s 10ms/step - loss: 1.5180 - accuracy: 0.4509 - val_loss: 1.4487 - val_accuracy: 0.4736
# Epoch 3/5
# 391/391 [==============================] - 3s 8ms/step - loss: 1.4054 - accuracy: 0.4954 - val_loss: 1.3428 - val_accuracy: 0.5162
# Epoch 4/5
# 391/391 [==============================] - 3s 8ms/step - loss: 1.3312 - accuracy: 0.5276 - val_loss: 1.2956 - val_accuracy: 0.5369
# Epoch 5/5
# 391/391 [==============================] - 4s 9ms/step - loss: 1.2703 - accuracy: 0.5485 - val_loss: 1.2583 - val_accuracy: 0.5480
# <built-in method keys of dict object at 0x7fab0b2e4b80>
# Epoch 1/50
# 391/391 [==============================] - 6s 10ms/step - loss: 1.7879 - accuracy: 0.3480 - val_loss: 1.4888 - val_accuracy: 0.4543
# Epoch 2/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.3503 - accuracy: 0.5115 - val_loss: 1.2246 - val_accuracy: 0.5549
# Epoch 3/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.1394 - accuracy: 0.5933 - val_loss: 1.0349 - val_accuracy: 0.6259
# Epoch 4/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.9766 - accuracy: 0.6558 - val_loss: 0.9403 - val_accuracy: 0.6709
# Epoch 5/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.8451 - accuracy: 0.7025 - val_loss: 0.9107 - val_accuracy: 0.6822
# Epoch 6/50
# 391/391 [==============================] - 4s 10ms/step - loss: 0.7265 - accuracy: 0.7458 - val_loss: 0.8680 - val_accuracy: 0.7025
# Epoch 7/50
# 391/391 [==============================] - 3s 9ms/step - loss: 0.6220 - accuracy: 0.7822 - val_loss: 0.8279 - val_accuracy: 0.7226
# Epoch 8/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.5283 - accuracy: 0.8164 - val_loss: 0.8147 - val_accuracy: 0.7275
# Epoch 9/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.4363 - accuracy: 0.8478 - val_loss: 0.9910 - val_accuracy: 0.7124
# Epoch 10/50
# 391/391 [==============================] - 4s 9ms/step - loss: 0.3522 - accuracy: 0.8756 - val_loss: 0.8751 - val_accuracy: 0.7372
# Epoch 11/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.2774 - accuracy: 0.9038 - val_loss: 0.9800 - val_accuracy: 0.7349
# Epoch 12/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.2187 - accuracy: 0.9237 - val_loss: 1.1926 - val_accuracy: 0.7341
# Epoch 13/50
# 391/391 [==============================] - 4s 9ms/step - loss: 0.1746 - accuracy: 0.9389 - val_loss: 1.2707 - val_accuracy: 0.7294
# Epoch 14/50
# 391/391 [==============================] - 4s 9ms/step - loss: 0.1458 - accuracy: 0.9488 - val_loss: 1.5847 - val_accuracy: 0.7157
# Epoch 15/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.1217 - accuracy: 0.9573 - val_loss: 1.5166 - val_accuracy: 0.7318
# Epoch 16/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.1121 - accuracy: 0.9614 - val_loss: 1.5532 - val_accuracy: 0.7329
# Epoch 17/50
# 391/391 [==============================] - 4s 10ms/step - loss: 0.1022 - accuracy: 0.9651 - val_loss: 1.8174 - val_accuracy: 0.7238
# Epoch 18/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0977 - accuracy: 0.9669 - val_loss: 1.7050 - val_accuracy: 0.7114
# Epoch 19/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0883 - accuracy: 0.9702 - val_loss: 1.8107 - val_accuracy: 0.7366
# Epoch 20/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0843 - accuracy: 0.9718 - val_loss: 1.8884 - val_accuracy: 0.7291
# Epoch 21/50
# 391/391 [==============================] - 4s 10ms/step - loss: 0.0813 - accuracy: 0.9732 - val_loss: 1.8272 - val_accuracy: 0.7356
# Epoch 22/50
# 391/391 [==============================] - 3s 9ms/step - loss: 0.0772 - accuracy: 0.9744 - val_loss: 1.9185 - val_accuracy: 0.7314
# Epoch 23/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0747 - accuracy: 0.9755 - val_loss: 1.9708 - val_accuracy: 0.7311
# Epoch 24/50
# 391/391 [==============================] - 4s 10ms/step - loss: 0.0723 - accuracy: 0.9770 - val_loss: 2.1499 - val_accuracy: 0.7326
# Epoch 25/50
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0696 - accuracy: 0.9779 - val_loss: 2.2337 - val_accuracy: 0.7165
# Epoch 26/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0721 - accuracy: 0.9769 - val_loss: 2.2705 - val_accuracy: 0.7259
# Epoch 27/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0643 - accuracy: 0.9797 - val_loss: 2.3968 - val_accuracy: 0.7165
# Epoch 28/50
# 391/391 [==============================] - 4s 10ms/step - loss: 0.0683 - accuracy: 0.9787 - val_loss: 2.3056 - val_accuracy: 0.7258
# Epoch 29/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0641 - accuracy: 0.9801 - val_loss: 2.4864 - val_accuracy: 0.7199
# Epoch 30/50
# 391/391 [==============================] - 3s 9ms/step - loss: 0.0650 - accuracy: 0.9803 - val_loss: 2.2857 - val_accuracy: 0.7242
# Epoch 31/50
# 391/391 [==============================] - 4s 10ms/step - loss: 0.0646 - accuracy: 0.9806 - val_loss: 2.3960 - val_accuracy: 0.7327
# Epoch 32/50
# 391/391 [==============================] - 3s 9ms/step - loss: 0.0584 - accuracy: 0.9820 - val_loss: 2.4705 - val_accuracy: 0.7265
# Epoch 33/50
# 391/391 [==============================] - 3s 9ms/step - loss: 0.0637 - accuracy: 0.9801 - val_loss: 2.4809 - val_accuracy: 0.7325
# Epoch 34/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0626 - accuracy: 0.9820 - val_loss: 2.5982 - val_accuracy: 0.7265
# Epoch 35/50
# 391/391 [==============================] - 4s 10ms/step - loss: 0.0614 - accuracy: 0.9813 - val_loss: 2.5996 - val_accuracy: 0.7275
# Epoch 36/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0622 - accuracy: 0.9819 - val_loss: 2.6403 - val_accuracy: 0.7244
# Epoch 37/50
# 391/391 [==============================] - 3s 9ms/step - loss: 0.0637 - accuracy: 0.9813 - val_loss: 2.7975 - val_accuracy: 0.7286
# Epoch 38/50
# 391/391 [==============================] - 4s 10ms/step - loss: 0.0592 - accuracy: 0.9842 - val_loss: 2.5853 - val_accuracy: 0.7246
# Epoch 39/50
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0573 - accuracy: 0.9832 - val_loss: 2.6707 - val_accuracy: 0.7260
# Epoch 40/50
# 391/391 [==============================] - 3s 9ms/step - loss: 0.0616 - accuracy: 0.9831 - val_loss: 2.6992 - val_accuracy: 0.7339
# Epoch 41/50
# 391/391 [==============================] - 3s 9ms/step - loss: 0.0611 - accuracy: 0.9832 - val_loss: 2.7289 - val_accuracy: 0.7268
# Epoch 42/50
# 391/391 [==============================] - 4s 10ms/step - loss: 0.0595 - accuracy: 0.9832 - val_loss: 2.5630 - val_accuracy: 0.7358
# Epoch 43/50
# 391/391 [==============================] - 3s 9ms/step - loss: 0.0537 - accuracy: 0.9850 - val_loss: 2.9549 - val_accuracy: 0.7177
# Epoch 44/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0568 - accuracy: 0.9838 - val_loss: 3.2591 - val_accuracy: 0.7301
# Epoch 45/50
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0576 - accuracy: 0.9842 - val_loss: 3.0790 - val_accuracy: 0.7286
# Epoch 46/50
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0576 - accuracy: 0.9833 - val_loss: 3.0706 - val_accuracy: 0.7292
# Epoch 47/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0533 - accuracy: 0.9855 - val_loss: 3.0419 - val_accuracy: 0.7254
# Epoch 48/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0605 - accuracy: 0.9835 - val_loss: 2.8336 - val_accuracy: 0.7429
# Epoch 49/50
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0525 - accuracy: 0.9855 - val_loss: 3.0687 - val_accuracy: 0.7351
# Epoch 50/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0585 - accuracy: 0.9850 - val_loss: 2.9340 - val_accuracy: 0.7331
# <built-in method keys of dict object at 0x7fab2015a040>
# Epoch 1/5
# 391/391 [==============================] - 6s 11ms/step - loss: 2.0070 - accuracy: 0.2721 - val_loss: 1.8855 - val_accuracy: 0.3296
# Epoch 2/5
# 391/391 [==============================] - 3s 9ms/step - loss: 1.6887 - accuracy: 0.3953 - val_loss: 1.6568 - val_accuracy: 0.4081
# Epoch 3/5
# 391/391 [==============================] - 3s 9ms/step - loss: 1.5703 - accuracy: 0.4347 - val_loss: 1.6233 - val_accuracy: 0.4323
# Epoch 4/5
# 391/391 [==============================] - 3s 9ms/step - loss: 1.4917 - accuracy: 0.4647 - val_loss: 1.5268 - val_accuracy: 0.4401
# Epoch 5/5
# 391/391 [==============================] - 4s 10ms/step - loss: 1.4293 - accuracy: 0.4919 - val_loss: 1.4439 - val_accuracy: 0.4933
# <built-in method keys of dict object at 0x7fab08218740>

# %%
### Create plots that show the losses and metrics for each of these runs, and
### comment on the results in your report.
plt.figure()
plt.plot(history.history['loss'], label='Training_sgd_D')
plt.plot(history.history['val_loss'], label='Validation_sgd_D')
plt.plot(history_S_1.history['loss'], label='Training_sgd_L')
plt.plot(history_S_1.history['val_loss'], label='Validation_sgd_L')
plt.legend()
plt.figure()
plt.plot(history_1.history['loss'], label='Training_Adam_D')
plt.plot(history_1.history['val_loss'], label='Validation_Adam_D')
plt.plot(history_1_A.history['loss'], label='Training_Adam_L')
plt.plot(history_1_A.history['val_loss'], label='Validation_Adam_L')
plt.legend()
plt.figure()
plt.plot(history_2.history['loss'], label='Training_RMSprop_D')
plt.plot(history_2.history['val_loss'], label='Validation_RMSprop_D')
plt.plot(history_2_A.history['loss'], label='Training_RMSprop_L')
plt.plot(history_2_A.history['val_loss'], label='Validation_RMSprop_L')
plt.legend()
#plt.title('Model Loss Training')

'''
plt.figure()
#plt.plot(history.history['accuracy'], label='Training')
#plt.plot(history.history['val_accuracy'], label='Validation')
#plt.plot(history_1.history['accuracy'], label='Training_1')
#plt.plot(history_1.history['val_accuracy'], label='Validation_1')
plt.plot(history_2.history['accuracy'], label='Training_2')
plt.plot(history_2.history['val_accuracy'], label='Validation_2')
plt.legend()
plt.title('Model Accuracy')
'''
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ea09f707f11c> in <module>
#       1 ### Create plots that show the losses and metrics for each of these runs, and
#       2 ### comment on the results in your report.
# ----> 3 plt.figure()
#       4 plt.plot(history.history['loss'], label='Training_sgd_D')
#       5 plt.plot(history.history['val_loss'], label='Validation_sgd_D')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # Task 3 - Testing Batch Sizes
#
# The batch size can heavily influence the amount of time it takes to train a model. Vary the batch size used to train the model and, utilising the Early Stopping callback provided, create plots that show how the time per epoch and total training time changes.
#
# Comment on these results in your report—consider both how the batch size influences the number of epochs it takes to reach a solution, and how long each epoch takes to run. Why is this the case?

# %%
### Train the model with a range of different batch sizes, resetting the weights
### each time. Use an Early Stopping callback to prevent the model training for
### too long.

Early_Stop = callbacks.EarlyStopping(monitor='val_loss', patience=3)
epochs=50

def reinitialize(cifar_model):
  cifar_model.compile(optimizer=optimizers.SGD(),
                    loss=losses.SparseCategoricalCrossentropy(from_logits=True),
                    metrics=['accuracy'])

history_3 = cifar_model.fit(x=x_train, y=y_train, epochs=50,
                          validation_data=(x_test, y_test),
                          batch_size=128, callbacks=Early_Stop)
print(history_3.history.keys)

def reinitialize(cifar_model):
  cifar_model.compile(optimizer=optimizers.SGD(),
                    loss=losses.SparseCategoricalCrossentropy(from_logits=True),
                    metrics=['accuracy'])
  
history_4 = cifar_model.fit(x=x_train, y=y_train, epochs=50,
                          validation_data=(x_test, y_test),
                          batch_size=64, callbacks=Early_Stop)
print(history_4.history.keys)

def reinitialize(cifar_model):
  cifar_model.compile(optimizer=optimizers.SGD(),
                    loss=losses.SparseCategoricalCrossentropy(from_logits=True),
                    metrics=['accuracy'])
  
history_5 = cifar_model.fit(x=x_train, y=y_train, epochs=50,
                          validation_data=(x_test, y_test),
                          batch_size=512, callbacks=Early_Stop)
print(history_5.history.keys)

plt.figure()
plt.plot(epochs, history_3.history['loss'], label='Training')
plt.plot(epochs, history_3.history['val_loss'], label='Validation')
#plt.plot(history_3.history['accuracy'], label='Training_A')
#plt.plot(history_3.history['val_accuracy'], label='Validation_A')
plt.legend()
plt.title('Model 128')

plt.figure()
plt.plot(epochs, history_4.history['loss'], label='Training')
plt.plot(epochs, history_4.history['val_loss'], label='Validation')
#plt.plot(history_4.history['accuracy'], label='Training_A')
#plt.plot(history_4.history['val_accuracy'], label='Validation_A')
plt.legend()
plt.title('Model 64')

plt.figure()
plt.plot(epochs, history_5.history['loss'], label='Training')
plt.plot(epochs, history_5.history['val_loss'], label='Validation')
#plt.plot(history_5.history['accuracy'], label='Training_A')
#plt.plot(history_5.history['val_accuracy'], label='Validation_A')
plt.legend()
plt.title('Model 512')


plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-327e9df42731> in <module>
#       6 epochs=50
#       7
# ----> 8 epochs = epochs.reshape(-1,)
#       9
#      10 def reinitialize(cifar_model):
#
# AttributeError: 'int' object has no attribute 'reshape'

# %% [markdown]
# # Task 4 - Adding Regularisation
#
# The model as provided does not contain any regularisation techniques. Edit the model architecture to include at least two examples of regularisation. Retrain the model using the new architecture, and repeat the analysis performed in task 1.
#
# In your report, compare and contrast the results from this task, with those from the initial model configuration. Explain HOW and WHY the results are different, with consideration to the predicted classifications, losses and metrics.

# %%
### Update the model architecture to include at least two types of regularization.
### Train the model using the ideal settings found in previous tasks.

# %%
### Repeat your analysis from task 1, creating plots of the losses, metrics AND
### predicted classifications of images in the test set.
